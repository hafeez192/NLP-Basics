# %%
import nltk
import gensim
from nltk.corpus import abc

# %%
model = gensim.models.Word2Vec(abc.sents())

# %%
X = list(model.wv.key_to_index)

# %%
data = model.wv.most_similar('science')

# %%
print(data)
# Out:
# [('law', 0.9130120873451233), ('general', 0.9115952253341675), ('policy', 0.9079408645629883), ('agriculture', 0.9009977579116821), ('discussion', 0.9009947180747986), ('education', 0.8992557525634766), ('media', 0.8986539244651794), ('practice', 0.8984860181808472), ('physics', 0.8912696242332458), ('department', 0.8912622928619385)]
